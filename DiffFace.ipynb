# %% [markdown]
# # Clone code from github

# %%
# !git clone https://github.com/ashrfras/DiffFace.git
# Out:
# Cloning into 'DiffFace'...
# remote: Enumerating objects: 779, done.
# remote: Counting objects: 100% (779/779), done.
# remote: Compressing objects: 100% (645/645), done.
# remote: Total 779 (delta 478), reused 385 (delta 118), pack-reused 0 (from 0)
# Receiving objects: 100% (779/779), 5.42 MiB | 8.43 MiB/s, done.
# Resolving deltas: 100% (478/478), done.

# %% [markdown]
# # Setup env & requirements

# %%
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# %cd "/content/DiffFace/"
# !pip install -r requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 GB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 48.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 70.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1+cu121
#     Uninstalling torch-2.3.1+cu121:
#       Successfully uninstalled torch-2.3.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.1+cu121
#     Uninstalling torchvision-0.18.1+cu121:
#       Successfully uninstalled torchvision-0.18.1+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.3.1+cu121
#     Uninstalling torchaudio-2.3.1+cu121:
#       Successfully uninstalled torchaudio-2.3.1+cu121
# ...

# %% [markdown]
# # Import Pretrained Weights from your Drive

# %% [markdown]
# Make sure you have a file in your MyDrive folder with name checkpoints.zip.

# %%
# Install gdown if it's not already installed
# !pip install gdown

# Import the gdown module
import gdown

# Google Drive file ID
file_id = "1z7u38LsVaPV2ew_Ci_YLf48i-_Cge8po"
# The destination where you want to save the file
output = "/content/DiffFace/checkpoints.zip"

# Download the file from Google Drive
gdown.download(f"https://drive.google.com/uc?id={file_id}", output, quiet=False)

# Change the working directory to /content/DiffFace/
# %cd "/content/DiffFace/"

# Unzip the downloaded checkpoints.zip file
# !unzip checkpoints.zip

# Uncomment these lines if you want to use them

# Remove the 'aligned' directory if it exists
# !rm -r "/content/DiffFace/data/dst/aligned/aligned"

# Copy the 'aligned' directory within the 'dst' directory
# !cp -r "/content/DiffFace/data/dst/aligned/aligned" "/content/DiffFace/data/dst"

# Copy 'aligned' directory from Google Drive to 'DiffFace'
# !cp -r "/content/drive/MyDrive/dst/aligned" "/content/DiffFace/data/dst/aligned"

# Copy 'dst' directory from 'DiffFace' back to Google Drive
# !cp -r "/content/DiffFace/data/dst" "/content/drive/MyDrive"

# Copy 'model_generic_xseg' directory from Google Drive to 'DiffFace/checkpoints'
# !cp -r "/content/drive/MyDrive/model_generic_xseg" "/content/DiffFace/checkpoints"
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1z7u38LsVaPV2ew_Ci_YLf48i-_Cge8po
# From (redirected): https://drive.google.com/uc?id=1z7u38LsVaPV2ew_Ci_YLf48i-_Cge8po&confirm=t&uuid=a53e9028-4a44-48ee-8404-b2acf7a144e4
# To: /content/DiffFace/checkpoints.zip
# 100%|██████████| 3.07G/3.07G [00:20<00:00, 148MB/s]
# /content/DiffFace
# Archive:  checkpoints.zip
# replace checkpoints/Arcface.tar? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace checkpoints/FaceParser.pth? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace checkpoints/GazeEstimator.pt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace checkpoints/Model.pt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %% [markdown]
# # Inference Using Pretrained Model

# %%
# %cd "/content/DiffFace/"
# !python main.py --iterations_num 10 --loss_weight 4000


#!zip -0 -r -q data.zip data
# !cp "/content/DiffFace/data/dst/merged/dst.jpg" "/content/drive/MyDrive/dsti.jpg"
#!rm -f /content/DiffFace/data/dst/aligned/0010*
# Out:
# /content/DiffFace
# Checking source directory:
# ['aligned', 'src.jpg']
# Checking destination directory:
# ['merged', 'dst.jpg', 'aligned', 'preded']
# Files found with pattern: ./data/src/src.*
# Files found with pattern: ./data/dst/dst.*
# Source Extension: jpg
# Destination Extension: jpg
# Requested Crop
# Downloading: "https://github.com/mantasu/face-crop-plus/releases/download/v1.0.0/retinaface_detector.pth" to /root/.cache/torch/hub/checkpoints/retinaface_detector.pth
# 100% 104M/104M [00:03<00:00, 35.9MB/s]
# Processing:   0% 0/1 [00:00<?, ?it/s]/content/DiffFace/face_crop_plus/utils.py:264: UserWarning: Could not read the image ./data/src/aligned
#   warnings.warn(f"Could not read the image {path}")
# Processing: 100% 1/1 [00:09<00:00,  9.86s/it]
# Processing:   0% 0/1 [00:00<?, ?it/s]/content/DiffFace/face_crop_plus/utils.py:264: UserWarning: Could not read the image ./data/dst/merged
#   warnings.warn(f"Could not read the image {path}")
# ...

# %%
# !rm -r /content/DiffFace/data/*.mp4
# !rm -r /content/DiffFace/checkpoints*

# !mkdir data/dst
